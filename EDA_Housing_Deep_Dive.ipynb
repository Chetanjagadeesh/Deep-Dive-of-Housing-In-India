# %% [markdown]
# Group Members:
#   - Chetan Jagadeesh
#   - Sahil Joshi
#   - Kshitiz Pradeep Gupta
#   - Pulkit Pradeep Gupta

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
master_df = pd.read_csv('/content/drive/MyDrive/master_df_with_column_names.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
master_df.head()
# Out:
#   State Code                 State Name  District Code District Name  \
# 0         35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
# 1         35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
# 2         35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
# 3         35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
# 4         35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
#
#    Tehsil Code  Tehsil Name  Town Code/Village code  Ward No  \
# 0            0     Nicobars                       0        0
# 1            0     Nicobars                       0        0
# 2         5916  Car Nicobar                       0        0
# 3         5916  Car Nicobar                       0        0
# 4         5916  Car Nicobar                  645012        0
#
#                 Area Name Rural/Urban  ...  \
# 0     District - Nicobars       Total  ...
# 1     District - Nicobars       Rural  ...
# 2  Sub-Dist - Car Nicobar       Total  ...
# ...

# %%
master_df.shape
# Out:
# (704765, 145)

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704765 entries, 0 to 704764
# Columns: 145 entries, State Code to Households by Type of Structure of Census Houses: Unclassifiable
# dtypes: float64(133), int64(6), object(6)
# memory usage: 779.7+ MB

# %%
master_df.describe()
# Out:
#        District Code    Tehsil Code  Town Code/Village code        Ward No  \
# count  704765.000000  704765.000000           704765.000000  704765.000000
# mean      324.321548    3042.075608           372488.060419       1.945511
# std       172.767364    7461.068937           238540.639863      21.177628
# min         1.000000       0.000000                0.000000       0.000000
# 25%       175.000000     889.000000           170066.000000       0.000000
# 50%       343.000000    2445.000000           361244.000000       0.000000
# 75%       464.000000    3730.000000           548128.000000       0.000000
# max       640.000000   99999.000000           804041.000000    8501.000000
#
#        Number of households with condition of Census House as: Total (Total)  \
# count                                           704765.0
# mean                                               100.0
# std                                                  0.0
# ...

# %%
master_df.isna().sum()
# Out:
# State Code                                                           0
# State Name                                                           0
# District Code                                                        0
# District Name                                                        0
# Tehsil Code                                                          0
#                                                                     ..
# Households by Type of Structure of Census Houses: Semi-Permanent     0
# Households by Type of Structure of Census Houses: Total Temporary    0
# Households by Type of Structure of Census Houses: Serviceable        0
# Households by Type of Structure of Census Houses: Non-Serviceable    0
# Households by Type of Structure of Census Houses: Unclassifiable     0
# Length: 145, dtype: int64

# %%
master_df.columns.tolist()
# Out:
# ['State Code',
#  'State Name',
#  'District Code',
#  'District Name',
#  'Tehsil Code',
#  'Tehsil Name',
#  'Town Code/Village code',
#  'Ward No',
#  'Area Name',
#  'Rural/Urban',
#  'Number of households with condition of Census House as: Total (Total)',
#  'Number of households with condition of Census House as: Total (Good)',
#  'Number of households with condition of Census House as: Total (Livable)',
#  'Number of households with condition of Census House as: Total (Dilapidated)',
#  'Number of households with condition of Census House as: Residence (Total)',
#  'Number of households with condition of Census House as: Residence (Good)',
#  'Number of households with condition of Census House as: Residence (Livable)',
#  'Number of households with condition of Census House as: Residence (Dilapidated)',
#  'Number of households with condition of Census House as: Residence-cum-other use (Total)',
# ...

# %%
master_df.groupby(['State Name']).head()
# Out:
#        State Code                 State Name  District Code District Name  \
# 0              35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
# 1              35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
# 2              35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
# 3              35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
# 4              35  ANDAMAN & NICOBAR ISLANDS            638      Nicobars
# ...           ...                        ...            ...           ...
# 703742         15                    MIZORAM            283        Aizawl
# 703743         15                    MIZORAM            283        Aizawl
# 703744         15                    MIZORAM            283        Aizawl
# 703745         15                    MIZORAM            283        Aizawl
# 703746         15                    MIZORAM            283        Aizawl
#
#         Tehsil Code       Tehsil Name  Town Code/Village code  Ward No  \
# ...

# %% [markdown]
# ## Number of states having maximum number of households as "good"

# %%
master_df_groupedby = master_df[['State Name', 'Number of households with condition of Census House as: Total (Good)']].groupby(['State Name']).sum().sort_values(['Number of households with condition of Census House as: Total (Good)'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Number of households with condition of Census House as: Total (Good)
# State Name
# UTTAR PRADESH                                                      4603940.5
# MADHYA PRADESH                                                     2910739.9
# MAHARASHTRA                                                        2801313.0
# RAJASTHAN                                                          2295693.0
# ANDHRA PRADESH                                                     2126994.6
# TAMIL NADU                                                         2072402.1
# KARNATAKA                                                          1794419.5
# WEST BENGAL                                                        1509117.6
# BIHAR                                                              1508350.5
# HIMACHAL PRADESH                                                   1303241.4
# GUJARAT                                                            1261945.7
# ...

# %%
master_df_groupedby.plot(kind='bar', title='State-wise data of houses that are good', 
                         ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Uttar Pradesh has the highest number of households as "good", while understandably UTs of Chandigarh & Lakshadweep have it as lowest

# %% [markdown]
# ## Number of states having maximum households as "livable"

# %%
master_df_groupedby = master_df[['State Name', 'Number of households with condition of Census House as: Total (Livable)']].groupby(['State Name']).sum().sort_values(['Number of households with condition of Census House as: Total (Livable)'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Number of households with condition of Census House as: Total (Livable)
# State Name
# UTTAR PRADESH                                                      5772264.6
# ODISHA                                                             3438793.2
# MADHYA PRADESH                                                     2862815.8
# BIHAR                                                              2568359.0
# RAJASTHAN                                                          2439957.5
# WEST BENGAL                                                        2235242.6
# MAHARASHTRA                                                        1876634.1
# JHARKHAND                                                          1825048.4
# ASSAM                                                              1650979.7
# KARNATAKA                                                          1412190.0
# CHHATTISGARH                                                       1218435.1
# ...

# %%
master_df_groupedby.plot(kind='bar', title='State-wise data of houses that are livable', 
                         ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Again, Uttar Pradesh wins the pie here. It has the highest number of households qualified as "livable", while UTs of Chandigarh and Lakshadweep have it lowest

# %% [markdown]
# ## Number of states having maximum households as "dilapidated"

# %%
master_df_groupedby = master_df[['State Name', 'Number of households with condition of Census House as: Total (Dilapidated)']].groupby(['State Name']).sum().sort_values(['Number of households with condition of Census House as: Total (Dilapidated)'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Number of households with condition of Census House as: Total (Dilapidated)
# State Name
# UTTAR PRADESH                                                       826182.2
# WEST BENGAL                                                         532627.7
# ODISHA                                                              431883.1
# BIHAR                                                               333085.5
# MAHARASHTRA                                                         310550.7
# MADHYA PRADESH                                                      271635.6
# ASSAM                                                               270249.7
# RAJASTHAN                                                           205047.3
# KARNATAKA                                                           179603.1
# JHARKHAND                                                           154111.1
# ANDHRA PRADESH                                                      135423.7
# ...

# %%
master_df_groupedby.plot(kind='bar', title='State-wise data of houses that are dilapidated', 
                         ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Uttar Pradesh has the highest number of dilapidated households, while Daman & Diu/Lakshadweep have the lowest

# %% [markdown]
# ## State-wise house & roof type data

# %%
master_df_groupedby = master_df[['State Name', 'Material of Roof: Grass/Thatch/Bamboo/Wood/Mud etc.',
 'Material of Roof: Plastic/Polythene',
 'Material of Roof: Hand made Tiles',
 'Material of Roof: Machine made Tiles',
 'Material of Roof: Burnt Brick',
 'Material of Roof: Stone/Slate',
 'Material of Roof: G.I./Metal/Asbestos sheets',
 'Material of Roof: Concrete',
 'Material of Roof: Any other material']].groupby(['State Name']).sum().sort_values(['Material of Roof: Grass/Thatch/Bamboo/Wood/Mud etc.',
 'Material of Roof: Plastic/Polythene',
 'Material of Roof: Hand made Tiles',
 'Material of Roof: Machine made Tiles',
 'Material of Roof: Burnt Brick',
 'Material of Roof: Stone/Slate',
 'Material of Roof: G.I./Metal/Asbestos sheets',
 'Material of Roof: Concrete',
 'Material of Roof: Any other material'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Material of Roof: Grass/Thatch/Bamboo/Wood/Mud etc.  \
# State Name
# UTTAR PRADESH                                                      2777860.2
# ODISHA                                                             2045129.4
# BIHAR                                                              1346258.9
# RAJASTHAN                                                           961747.0
# WEST BENGAL                                                         886374.5
# ASSAM                                                               738375.8
# MADHYA PRADESH                                                      658606.6
# ANDHRA PRADESH                                                      638583.2
# TAMIL NADU                                                          582329.5
# JHARKHAND                                                           517633.7
# KARNATAKA                                                           445891.8
# ...

# %%
master_df_groupedby.plot(kind='bar', title='State-wise Roof Type Data', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Uttar Pradesh has the highest number of housebolds with thatched & stoned roofs, while Madhya Pradesh has the highest number of households with roofs made of home-made tiles

# %% [markdown]
# ## State-wise house & wall type data

# %%
master_df_groupedby = master_df[['State Name', 'Material of Wall: Grass/Thatch/Bamboo etc.',
 'Material of Wall: Plastic/Polythene',
 'Material of Wall: Mud/Unburnt brick',
 'Material of Wall: Wood',
 'Material of Wall: Stone not packed with mortar',
 'Material of Wall: Stone packed with mortar',
 'Material of Wall: G.I./Metal/Asbestos sheets',
 'Material of Wall: Burnt brick',
 'Material of Wall: Concrete',
 'Material of Wall: Any other material']].groupby(['State Name']).sum().sort_values(['Material of Wall: Grass/Thatch/Bamboo etc.',
 'Material of Wall: Plastic/Polythene',
 'Material of Wall: Mud/Unburnt brick',
 'Material of Wall: Wood',
 'Material of Wall: Stone not packed with mortar',
 'Material of Wall: Stone packed with mortar',
 'Material of Wall: G.I./Metal/Asbestos sheets',
 'Material of Wall: Burnt brick',
 'Material of Wall: Concrete',
 'Material of Wall: Any other material'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Material of Wall: Grass/Thatch/Bamboo etc.  \
# State Name
# ASSAM                                                       2026988.8
# BIHAR                                                        994747.0
# WEST BENGAL                                                  763284.8
# UTTAR PRADESH                                                650660.2
# MAHARASHTRA                                                  434297.1
# ARUNACHAL PRADESH                                            434012.6
# MEGHALAYA                                                    392622.1
# ODISHA                                                       376085.8
# MADHYA PRADESH                                               257170.5
# ANDHRA PRADESH                                               229745.1
# GUJARAT                                                      210843.0
# RAJASTHAN                                                    174531.8
# ...

# %%
master_df_groupedby.plot(kind='bar', title='State-wise Wall type data', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Uttar Pradesh has a very high number of households with walls made of burnt brick, while Madhya Pradesh has an unsually high number of households with walls made of mud/unburnt brick

# %% [markdown]
# ## State-wise house & floor type data

# %%
master_df_groupedby = master_df[['State Name', 'Material of Floor: Mud',
 'Material of Floor: Wood/Bamboo',
 'Material of Floor: Burnt Brick',
 'Material of Floor: Stone',
 'Material of Floor: Cement',
 'Material of Floor: Mosaic/Floor tiles',
 'Material of Floor: Any other material',
 'Number of Dwelling Rooms: No exclusive room']].groupby(['State Name']).sum().sort_values(['Material of Floor: Mud',
 'Material of Floor: Wood/Bamboo',
 'Material of Floor: Burnt Brick',
 'Material of Floor: Stone',
 'Material of Floor: Cement',
 'Material of Floor: Mosaic/Floor tiles',
 'Material of Floor: Any other material',
 'Number of Dwelling Rooms: No exclusive room'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Material of Floor: Mud  \
# State Name
# UTTAR PRADESH                           8832374.8
# MADHYA PRADESH                          4933239.4
# ODISHA                                  3762342.7
# BIHAR                                   3599237.0
# WEST BENGAL                             3196984.4
# MAHARASHTRA                             2961376.4
# JHARKHAND                               2657807.1
# RAJASTHAN                               2598187.3
# ASSAM                                   2264664.5
# CHHATTISGARH                            1927774.7
# ANDHRA PRADESH                          1188799.9
# KARNATAKA                               1031691.8
# GUJARAT                                  966987.9
# UTTARAKHAND                              946769.5
# HIMACHAL PRADESH                         676372.0
# TAMIL NADU                               620712.0
# PUNJAB                                   467600.7
# ...

# %%
master_df_groupedby.plot(kind='bar', title='State-wise Floor Type Data', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Mud made floors dominate in Uttar Pradesh households, and a lot of other states. Tamil Nadu in particular breaks the mould - with the highest number of households having mosaic/floor tiles (instead of mud based)

# %% [markdown]
# ## Number of rooms in houses, state-wise data

# %%
master_df_groupedby = master_df[['State Name', 'Number of Dwelling Rooms: No exclusive room',
 'Number of Dwelling Rooms: One room',
 'Number of Dwelling Rooms: Two rooms',
 'Number of Dwelling Rooms: Three rooms',
 'Number of Dwelling Rooms: Four rooms',
 'Number of Dwelling Rooms: Five rooms',
 'Number of Dwelling Rooms: Six rooms and above']].groupby(['State Name']).sum().sort_values(['Number of Dwelling Rooms: No exclusive room',
 'Number of Dwelling Rooms: One room',
 'Number of Dwelling Rooms: Two rooms',
 'Number of Dwelling Rooms: Three rooms',
 'Number of Dwelling Rooms: Four rooms',
 'Number of Dwelling Rooms: Five rooms',
 'Number of Dwelling Rooms: Six rooms and above'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Number of Dwelling Rooms: No exclusive room  \
# State Name
# KARNATAKA                                                     589884.2
# UTTAR PRADESH                                                 461053.1
# TAMIL NADU                                                    307086.4
# MAHARASHTRA                                                   189021.6
# WEST BENGAL                                                   184572.5
# RAJASTHAN                                                     169121.6
# MADHYA PRADESH                                                168933.2
# BIHAR                                                         124733.8
# ODISHA                                                        106884.7
# ANDHRA PRADESH                                                103225.5
# JHARKHAND                                                      86450.1
# ASSAM                                                          82864.0
# ...

# %%
master_df_groupedby.plot(kind='bar', title='State-wise Number of Rooms Data', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Most states can be seen to have households with one room. Understandably one room & two room households dominate the curve across the nation

# %% [markdown]
# ## Finding out the household sizes, state-wise

# %%
master_df_groupedby = master_df[['State Name', 'Household size: 1',
 'Household size: 2',
 'Household size: 3',
 'Household size: 4',
 'Household size: 5',
 'Household size: 6-8',
 'Household size: 9+']].groupby(['State Name']).sum().sort_values(['Household size: 1',
 'Household size: 2',
 'Household size: 3',
 'Household size: 4',
 'Household size: 5',
 'Household size: 6-8',
 'Household size: 9+'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Household size: 1  Household size: 2  \
# State Name
# UTTAR PRADESH                       314985.6           718902.1
# MADHYA PRADESH                      267291.0           690820.6
# MAHARASHTRA                         226323.4           536675.3
# ODISHA                              218502.3           638494.6
# TAMIL NADU                          177813.5           429824.4
# ANDHRA PRADESH                      168812.4           448475.0
# UTTARAKHAND                         145778.2           170231.2
# WEST BENGAL                         143801.0           377741.6
# KARNATAKA                           137788.8           309645.8
# RAJASTHAN                           133906.1           391411.4
# CHHATTISGARH                        128053.2           296640.1
# HIMACHAL PRADESH                     98029.0           155392.5
# BIHAR                                96063.9           373496.9
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Household size by State', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### 3 and 4 person households dominate the graph here, nation wide. This is understandable.

# %% [markdown]
# ## Decoding ownership status of houses, state-wise

# %%
master_df_groupedby = master_df[['State Name', 'Ownership status: Owned',
 'Ownership status: Rented',
 'Ownership status: Any others']].groupby(['State Name']).sum().sort_values(['Ownership status: Owned',
 'Ownership status: Rented',
 'Ownership status: Any others'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Ownership status: Owned  Ownership status: Rented  \
# State Name
# UTTAR PRADESH                           10879605.9                  200299.0
# MADHYA PRADESH                           5711971.1                  186463.2
# ODISHA                                   4883330.1                  133907.3
# RAJASTHAN                                4714157.1                  123168.4
# MAHARASHTRA                              4455181.5                  350480.3
# BIHAR                                    4296504.9                   66831.8
# WEST BENGAL                              4056118.5                  105024.3
# JHARKHAND                                3060031.4                   67605.9
# KARNATAKA                                2945028.6                  337381.1
# ANDHRA PRADESH                           2922608.2                  309686.2
# ASSAM                                    2520412.9                   84566.6
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Household ownership by State', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Interestingly, most of the households surveyed across the nation reportedly were owned by the census participants. This is good!

# %% [markdown]
# ## States having maximum number of married couples per household

# %%
master_df_groupedby = master_df[['State Name', 'Married couple: None',
 'Married couple: 1',
 'Married couple: 2',
 'Married couple: 3',
 'Married couple: 4',
 'Married couple: 5+']].groupby(['State Name']).sum().sort_values(['Married couple: None',
 'Married couple: 1',
 'Married couple: 2',
 'Married couple: 3',
 'Married couple: 4',
 'Married couple: 5+'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Married couple: None  Married couple: 1  \
# State Name
# UTTAR PRADESH                         1004766.2          6841317.2
# ODISHA                                 673518.5          3851039.5
# MADHYA PRADESH                         639298.0          4352454.7
# MAHARASHTRA                            633305.6          3406863.1
# TAMIL NADU                             473350.4          2255814.3
# WEST BENGAL                            460824.2          3081647.7
# ANDHRA PRADESH                         452118.1          2459435.0
# KARNATAKA                              445512.9          2318955.6
# RAJASTHAN                              399797.9          3291419.7
# UTTARAKHAND                            362796.9          1032261.1
# BIHAR                                  352155.3          2936019.7
# JHARKHAND                              332705.7          2141136.4
# ASSAM                                  319427.4          2000117.9
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Number of married couples per household, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Majority of the households surveyed have just one married couple per household, indicating the dominance/rise of nuclear families in the country.

# %% [markdown]
# ## Finding the main source of drinking water, state-wise

# %%
master_df_groupedby = master_df[['State Name', 'Main Source of Drinking Water: Tapwater from treated source',
 'Main Source of Drinking Water: Tapwater from un-treated source',
 'Main Source of Drinking Water: Covered well',
 'Main Source of Drinking Water: Un-covered well',
 'Main Source of Drinking Water: Handpump',
 'Main Source of Drinking Water: Tubewell/Borehole',
 'Main Source of Drinking Water: Spring',
 'Main Source of Drinking Water: River/Canal',
 'Main Source of Drinking Water: Tank/Pond/Lake',
 'Main Source of Drinking Water: Other sources']].groupby(['State Name']).sum().sort_values(['Main Source of Drinking Water: Tapwater from treated source',
 'Main Source of Drinking Water: Tapwater from un-treated source',
 'Main Source of Drinking Water: Covered well',
 'Main Source of Drinking Water: Un-covered well',
 'Main Source of Drinking Water: Handpump',
 'Main Source of Drinking Water: Tubewell/Borehole',
 'Main Source of Drinking Water: Spring',
 'Main Source of Drinking Water: River/Canal',
 'Main Source of Drinking Water: Tank/Pond/Lake',
 'Main Source of Drinking Water: Other sources'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Main Source of Drinking Water: Tapwater from treated source  \
# State Name
# UTTAR PRADESH                                                      1771370.8
# MAHARASHTRA                                                        1681962.2
# TAMIL NADU                                                         1628459.2
# HIMACHAL PRADESH                                                   1510728.8
# ANDHRA PRADESH                                                     1087897.7
# RAJASTHAN                                                           923330.6
# KARNATAKA                                                           890762.8
# UTTARAKHAND                                                         889809.8
# MADHYA PRADESH                                                      503990.6
# HARYANA                                                             463630.8
# PUNJAB                                                              459093.3
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Drinking Water source in households, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Main source of drinking water in Uttar Pradesh (agriculutre belt) is expectedly Tubewell/Borewell. Relatively, this can also be seen in Madhya Pradesh, West Bengal & Bihar. Uncovered wells and tapwater are other close contenders, nation wide

# %% [markdown]
# ## Understanding where the household gets its drinking water from, state-wise

# %%
master_df_groupedby = master_df[['State Name', 'Location of drinking water source: Within premises',
 'Location of drinking water source: Near premises',
 'Location of drinking water source: Away']].groupby(['State Name']).sum().sort_values(['Location of drinking water source: Within premises',
 'Location of drinking water source: Near premises',
 'Location of drinking water source: Away'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Location of drinking water source: Within premises  \
# State Name
# UTTAR PRADESH                                                      5175320.0
# BIHAR                                                              2122497.3
# MAHARASHTRA                                                        2083347.8
# PUNJAB                                                             1284700.0
# ASSAM                                                              1276700.2
# WEST BENGAL                                                        1177505.9
# RAJASTHAN                                                          1074849.4
# GUJARAT                                                             995633.1
# MADHYA PRADESH                                                      976597.2
# KARNATAKA                                                           976151.9
# ANDHRA PRADESH                                                      944931.6
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Drinking Water source type in households, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Uttar Pradesh has the highest number of on-premise water facilities. Madhya Pradesh has the highest number of households reporting their water source as "nearby" and not on-premise. Sad state of affairs here - as the near premise reponse dominates across a lot of other states.

# %% [markdown]
# ## Main sources of household lighting, decoded state-wise

# %%
master_df_groupedby = master_df[['State Name', 'Main Source of lighting: Electricity',
 'Main Source of lighting: Kerosene',
 'Main Source of lighting: Solar energy',
 'Main Source of lighting: Other oil',
 'Main Source of lighting: Any other',
 'Main Source of lighting: No lighting']].groupby(['State Name']).sum().sort_values(['Main Source of lighting: Electricity',
 'Main Source of lighting: Kerosene',
 'Main Source of lighting: Solar energy',
 'Main Source of lighting: Other oil',
 'Main Source of lighting: Any other',
 'Main Source of lighting: No lighting'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Main Source of lighting: Electricity  \
# State Name
# MADHYA PRADESH                                        3684738.7
# MAHARASHTRA                                           3677905.2
# UTTAR PRADESH                                         3220320.9
# KARNATAKA                                             2983731.1
# RAJASTHAN                                             2863506.1
# TAMIL NADU                                            2845335.4
# ANDHRA PRADESH                                        2810666.0
# WEST BENGAL                                           1950720.6
# HIMACHAL PRADESH                                      1793906.8
# GUJARAT                                               1768043.7
# ODISHA                                                1643535.3
# CHHATTISGARH                                          1573651.5
# PUNJAB                                                1459189.4
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Main source of lighting in households, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Uttar Pradesh households are majorly fueled by kerosene. This is also noticeable in Odisha & Bihar. Madhya Pradesh leads the race in number of households having electricity.

# %% [markdown]
# ## Which states have the highest number of on-premise latrine facilities?

# %%
master_df_groupedby = master_df[['State Name', 'Number of households having latrine facility within the premises']].groupby(['State Name']).sum().sort_values(['Number of households having latrine facility within the premises'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Number of households having latrine facility within the premises
# State Name
# UTTAR PRADESH                                                      2775052.3
# MAHARASHTRA                                                        2022656.8
# WEST BENGAL                                                        1819572.6
# ASSAM                                                              1448498.1
# TAMIL NADU                                                         1255867.3
# HIMACHAL PRADESH                                                   1227931.3
# RAJASTHAN                                                          1202312.2
# KARNATAKA                                                          1136905.6
# PUNJAB                                                             1080503.6
# MADHYA PRADESH                                                     1037561.3
# ANDHRA PRADESH                                                      960441.9
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Households having on-premise latrine facilities, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Uttar Pradesh has the highest number of on-premise latrine facilities. This is mostly a factor of population size it seems.

# %% [markdown]
# ## Which states have the highest number of on-premise bathroom facilities?

# %%
master_df_groupedby = master_df[['State Name', 'Number of households having bathing facility within the premises: Yes (Bathroom)',
 'Number of households having bathing facility within the premises: Yes (Enclosure without roof)',
 'Number of households having bathing facility within the premises: No']].groupby(['State Name']).sum().sort_values(['Number of households having bathing facility within the premises: Yes (Bathroom)',
 'Number of households having bathing facility within the premises: Yes (Enclosure without roof)',
 'Number of households having bathing facility within the premises: No'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Number of households having bathing facility within the premises: Yes (Bathroom)  \
# State Name
# MAHARASHTRA                                                        2401481.4
# KARNATAKA                                                          2290743.6
# UTTAR PRADESH                                                      2280190.9
# TAMIL NADU                                                         1298424.5
# RAJASTHAN                                                          1269893.1
# HIMACHAL PRADESH                                                   1225656.3
# ANDHRA PRADESH                                                     1042191.0
# PUNJAB                                                              980561.3
# MADHYA PRADESH                                                      879247.9
# UTTARAKHAND                                                         776409.4
# GUJARAT                                                             730348.3
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Bathroom facilities in households, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Majority of households across the nation seem to have reported in against, of having on-premise bathroom facilities. No state seems to break the mould here.

# %% [markdown]
# ## Water water management: Closed, Open or No Drainage - State wise data

# %%
master_df_groupedby = master_df[['State Name', 'Waste water outlet connected to: Closed drainage',
 'Waste water outlet connected to: Open drainage',
 'Waste water outlet connected to: No drainage']].groupby(['State Name']).sum().sort_values(['Waste water outlet connected to: Closed drainage',
 'Waste water outlet connected to: Open drainage',
 'Waste water outlet connected to: No drainage'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Waste water outlet connected to: Closed drainage  \
# State Name
# UTTAR PRADESH                                                      979026.4
# MAHARASHTRA                                                        574229.6
# TAMIL NADU                                                         547502.8
# HIMACHAL PRADESH                                                   401592.6
# ANDHRA PRADESH                                                     324390.4
# KARNATAKA                                                          281556.1
# GUJARAT                                                            277243.6
# BIHAR                                                              244144.5
# PUNJAB                                                             227504.8
# MADHYA PRADESH                                                     215149.9
# RAJASTHAN                                                          207953.8
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Waste water management in households, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Barring Uttar Pradesh, most states seem to have households with waste water outlet connected to no drainage facility. Uttar Pradesh has majority households with waste water outlets to open drainages.

# %% [markdown]
# ## Fuel type used for cooking. A state wise look

# %%
master_df_groupedby = master_df[['State Name', 'Type of Fuel used for Cooking: Fire-wood',
 'Type of Fuel used for Cooking: Crop residue',
 'Type of Fuel used for Cooking: Cowdung cake',
 'Type of Fuel used for Cooking: Coal/Lignite/Charcoal',
 'Type of Fuel used for Cooking: Kerosene',
 'Type of Fuel used for Cooking: LPG/PNG',
 'Type of Fuel used for Cooking: Electricity',
 'Type of Fuel used for Cooking: Biogas',
 'Type of Fuel used for Cooking: Any other',
 'Type of Fuel used for Cooking: No cooking']].groupby(['State Name']).sum().sort_values(['Type of Fuel used for Cooking: Fire-wood',
 'Type of Fuel used for Cooking: Crop residue',
 'Type of Fuel used for Cooking: Cowdung cake',
 'Type of Fuel used for Cooking: Coal/Lignite/Charcoal',
 'Type of Fuel used for Cooking: Kerosene',
 'Type of Fuel used for Cooking: LPG/PNG',
 'Type of Fuel used for Cooking: Electricity',
 'Type of Fuel used for Cooking: Biogas',
 'Type of Fuel used for Cooking: Any other',
 'Type of Fuel used for Cooking: No cooking'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Type of Fuel used for Cooking: Fire-wood  \
# State Name
# UTTAR PRADESH                                             5879763.8
# MADHYA PRADESH                                            4608439.3
# ODISHA                                                    3825057.3
# RAJASTHAN                                                 3445313.2
# MAHARASHTRA                                               3378132.1
# KARNATAKA                                                 2627721.4
# ANDHRA PRADESH                                            2468627.7
# JHARKHAND                                                 2330013.1
# ASSAM                                                     2260901.6
# CHHATTISGARH                                              2059692.9
# WEST BENGAL                                               1798694.6
# BIHAR                                                     1531302.8
# TAMIL NADU                                                1530102.6
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Fuel type used in households, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Uttar Pradesh's majority households rely on fire wood. This can be observed as a trend across many states. The second close contender seems to be cowdung cake, aggregated.

# %% [markdown]
# ## Kitchen facilities available in households. A state wise look

# %%
master_df_groupedby = master_df[['State Name', 'Kitchen facility: Total',
 'Kitchen facility: Cooking inside house:',
 'Kitchen facility: Has Kitchen',
 'Kitchen facility: Does not have kitchen',
 'Kitchen facility: Cooking outside house:',
 'Kitchen facility: Has Kitchen.1',
 'Kitchen facility: Does not have kitchen.1',
 'Kitchen facility: No Cooking']].groupby(['State Name']).sum().sort_values(['Kitchen facility: Total',
 'Kitchen facility: Cooking inside house:',
 'Kitchen facility: Has Kitchen',
 'Kitchen facility: Does not have kitchen',
 'Kitchen facility: Cooking outside house:',
 'Kitchen facility: Has Kitchen.1',
 'Kitchen facility: Does not have kitchen.1',
 'Kitchen facility: No Cooking'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Kitchen facility: Total  \
# State Name
# UTTAR PRADESH                             11202400
# MADHYA PRADESH                             6045200
# ODISHA                                     5124700
# MAHARASHTRA                                4988500
# RAJASTHAN                                  4940700
# BIHAR                                      4409800
# WEST BENGAL                                4277000
# KARNATAKA                                  3386200
# ANDHRA PRADESH                             3286900
# JHARKHAND                                  3163400
# TAMIL NADU                                 3089300
# ASSAM                                      2716600
# CHHATTISGARH                               2314800
# GUJARAT                                    2089000
# HIMACHAL PRADESH                           1874500
# UTTARAKHAND                                1683800
# PUNJAB                                     1522600
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Kitchen facilities in households, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Majority of Indian households have on-premise kitchen facilities

# %% [markdown]
# ## Electrical assets available in households, state-wise data

# %%
master_df_groupedby = master_df[['State Name', 'Availability of assets: Radio/Transistor',
 'Availability of assets: Television',
 'Availability of assets: Computer/Laptop (With Internet)',
 'Availability of assets: Computer/Laptop (Without Internet)',
 'Availability of assets: Telephone/Mobile Phone (Landline only)',
 'Availability of assets: Telephone/Mobile Phone (Mobile only)',
 'Availability of assets: Telephone/Mobile Phone (Both)',
 'Availability of assets: Bicycle',
 'Availability of assets: Scooter/Motorcycle/Moped',
 'Availability of assets: Car/Jeep/Van',
 'Availability of assets: Households with TV']].groupby(['State Name']).sum().sort_values(['Availability of assets: Radio/Transistor',
 'Availability of assets: Television',
 'Availability of assets: Computer/Laptop (With Internet)',
 'Availability of assets: Computer/Laptop (Without Internet)',
 'Availability of assets: Telephone/Mobile Phone (Landline only)',
 'Availability of assets: Telephone/Mobile Phone (Mobile only)',
 'Availability of assets: Telephone/Mobile Phone (Both)',
 'Availability of assets: Bicycle',
 'Availability of assets: Scooter/Motorcycle/Moped',
 'Availability of assets: Car/Jeep/Van',
 'Availability of assets: Households with TV'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Availability of assets: Radio/Transistor  \
# State Name
# UTTAR PRADESH                                             2830511.7
# BIHAR                                                     1121647.5
# MADHYA PRADESH                                             804771.9
# RAJASTHAN                                                  739995.1
# ASSAM                                                      664810.4
# KARNATAKA                                                  655605.1
# WEST BENGAL                                                651617.1
# TAMIL NADU                                                 639693.0
# MAHARASHTRA                                                619838.0
# ODISHA                                                     574401.2
# HIMACHAL PRADESH                                           558651.4
# JHARKHAND                                                  536274.6
# JAMMU & KASHMIR                                            358099.5
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Electrical assets availability in households, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### The humble bicycle is "omnipresent" across a majority of Indian households. Mobile phones and televisions come off as strong runner ups.

# %% [markdown]
# ## Type of house structures surveyed, distributed state-wise

# %%
master_df_groupedby = master_df[['State Name', 'Households by Type of Structure of Census Houses: Permanent',
 'Households by Type of Structure of Census Houses: Semi-Permanent',
 'Households by Type of Structure of Census Houses: Total Temporary',
 'Households by Type of Structure of Census Houses: Serviceable',
 'Households by Type of Structure of Census Houses: Non-Serviceable',
 'Households by Type of Structure of Census Houses: Unclassifiable']].groupby(['State Name']).sum().sort_values(['Households by Type of Structure of Census Houses: Permanent',
 'Households by Type of Structure of Census Houses: Semi-Permanent',
 'Households by Type of Structure of Census Houses: Total Temporary',
 'Households by Type of Structure of Census Houses: Serviceable',
 'Households by Type of Structure of Census Houses: Non-Serviceable',
 'Households by Type of Structure of Census Houses: Unclassifiable'], ascending=False)

# %%
master_df_groupedby
# Out:
#                            Households by Type of Structure of Census Houses: Permanent  \
# State Name
# UTTAR PRADESH                                                      6865015.3
# RAJASTHAN                                                          3122686.3
# MAHARASHTRA                                                        2668959.2
# MADHYA PRADESH                                                     2131829.5
# ANDHRA PRADESH                                                     2058877.6
# BIHAR                                                              2040562.5
# TAMIL NADU                                                         2025088.0
# KARNATAKA                                                          1957195.0
# ODISHA                                                             1695024.9
# UTTARAKHAND                                                        1568217.3
# WEST BENGAL                                                        1439726.5
# ...

# %%
master_df_groupedby.plot(kind='bar', title='Type of households surveyed, state-wise', ylabel='Number of households',xlabel='State Name', figsize=(30, 10))

# %% [markdown]
# ### Permanent structured households dominate the census findings. Semi-permanent housholds can also be observed to be the secondary norm across states.
